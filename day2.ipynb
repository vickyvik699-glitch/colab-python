# %% [markdown]
# <a href="https://colab.research.google.com/github/vickyvik699-glitch/colab-python/blob/main/day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello vikash")
# Out:
# hello vikash

# %% [markdown]
# **OPERATORS**
# 1. arth -> +,-,*,/,//,%,**
# 2. relational -> >,<,>=,<=,==,!=
# 3. assignment -> +=,-=,*=,%=
# 4. logical -> and,or,not
# 5. bitwise -> &,|

# %%
#artt=hmatic operators
num1 = 10
num2 = 20
print(num1+num2)
# Out:
# 30

# %%
num1 = 100
num2 = 60
print(num1-num2)
# Out:
# 40

# %%
num1 = 5943930
num2 = 4908535
print(num1-num2)
# Out:
# 1035395

# %%
num1 = 5
num2 = 3
print(num1*num2)
# Out:
# 15

# %%
num1 = 13287
num2 = 38783
print(num1*num2)
# Out:
# 515309721

# %%
num1 = 20
num2 = 2
print(num1/num2)
# Out:
# 10.0

# %%
num1 = 100
num2 = 7
print(num1 //  num2) # double forward give output in integer (quotient)
# Out:
# 14

# %%
num1 = 5
num2 = 2
print(num1 ** num2)#power
# Out:
# 25

# %% [markdown]
# **relational opt**

# %%
num1 = 10
num2 = 20
print(num1>num2)
# Out:
# False

# %%
num1 = 10
num2 = 20
print(num1<num2)
# Out:
# True

# %%
num1 =10
num2 = 10
print(num1>=num2)
# Out:
# True

# %%
num1 = 10
num2 = 50
print(num1<=num2)
# Out:
# True

# %%
num1 = 20
num2 = 30
print(num1==num2)
# Out:
# False

# %%
num1 = 20
num2 = 30
print(num1!=num2)
# Out:
# True
