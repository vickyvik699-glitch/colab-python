# %% [markdown]
# <a href="https://colab.research.google.com/github/vickyvik699-glitch/colab-python/blob/main/day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello vikash")
# Out:
# hello vikash

# %% [markdown]
# **OPERATORS**
# 1. arth -> +,-,*,/,//,%,**
# 2. relational -> >,<,>=,<=,==,!=
# 3. assignment -> +=,-=,*=,%=
# 4. logical -> and,or,not
# 5. bitwise -> &,|

# %%
#artt=hmatic operators
num1 = 10
num2 = 20
print(num1+num2)
# Out:
# 30

# %%
num1 = 100
num2 = 60
print(num1-num2)
# Out:
# 40

# %%
num1 = 5943930
num2 = 4908535
print(num1-num2)
# Out:
# 1035395

# %%
num1 = 5
num2 = 3
print(num1*num2)
# Out:
# 15

# %%
num1 = 13287
num2 = 38783
print(num1*num2)
# Out:
# 515309721

# %%
num1 = 20
num2 = 2
print(num1/num2)
# Out:
# 10.0

# %%
num1 = 100
num2 = 7
print(num1 //  num2) # double forward give output in integer (quotient)
# Out:
# 14

# %%
num1 = 5
num2 = 2
print(num1 ** num2)#power
# Out:
# 25

# %% [markdown]
# **relational opr**

# %%
num1 = 10
num2 = 20
print(num1>num2)
# Out:
# False

# %%
num1 = 10
num2 = 20
print(num1<num2)
# Out:
# True

# %%
num1 =10
num2 = 10
print(num1>=num2)
# Out:
# True

# %%
num1 = 10
num2 = 50
print(num1<=num2)
# Out:
# True

# %%
num1 = 20
num2 = 30
print(num1==num2)
# Out:
# False

# %%
num1 = 20
num2 = 30
print(num1!=num2)
# Out:
# True

# %% [markdown]
# **ASSSIGNMENT OPR**

# %%
num1 = 10
num2 = 20
num1 += num2
print(num1)
# Out:
# 30

# %%
num1 = 20
num2 = 10
num1 -= num2
print(num1)
# Out:
# 10

# %%
num1 = 20
num2 = 10
num1 *= num2
print(num1)
# Out:
# 200

# %%
num1 = 20
num2 = 10
num1 /= num2
print(num1)
# Out:
# 2.0

# %%
num1 = 20
num2 = 10
num1 %= num2
print(num1)
# Out:
# 0

# %% [markdown]
# ** LOGICAL OPR**

# %%
#AND
num1 = 10
num2 = 20
print(num1 and num2) #If the first value is False (0, None, "", [], etc.), it returns the first value.
#Otherwise, it returns the second value.
# Out:
# 20

# %%
#OR
num1 =10
num2 = 20
print(num1 or num2)
#or operator, Python returns the first truthy value it finds
# Out:
# 20

# %%
#not
num1 = 10

print(not num1)
# Out:
# False

# %%
a = 10
b = 20
c = 30
print(not(a < b and b > c or c > a))
# Out:
# False

# %%
a = 'hello'
b = 5
c = []
print(a and b and c)
# Out:
# []

# %% [markdown]
# **bitwise opr**

# %%
num1 = 5
num2 = 3
print(num1 & num2)
# Out:
# 1
