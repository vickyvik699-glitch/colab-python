# %% [markdown]
# <a href="https://colab.research.google.com/github/vickyvik699-glitch/colab-python/blob/main/day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("vikash")
# Out:
# vikash

# %%
#variable
num = 10
print(num)
print(id(num))
print(type(num))

num1 = 10
print(num1)
print(id(num1))
# Out:
# 10
# 11645640
# <class 'int'>
# 10
# 11645640

# %%
#string
name = "vikash"
print(name)
print(id(name))
print(type(name))
# Out:
# vikash
# 133322627818928
# <class 'str'>

# %%
#bloolean
is_vikashactive = True
print(is_vikashactive)
print(id(is_vikashactive))
print(type(is_vikashactive))
# Out:
# True
# 10549600
# <class 'bool'>

# %%
#floot
price = 10.5
print(price)
print(id(price))
print(type(price))
# Out:
# 10.5
# 133322290190512
# <class 'float'>

# %%
roll_no = int(input("enter your roll no: ")) #Explicit
print(id(roll_no))
print(type(roll_no))
# Out:
# enter your roll no: 964
# 964
# 133322290538480
# <class 'int'>
